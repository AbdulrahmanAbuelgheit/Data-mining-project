# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     id      brand                                               name   price  \
# 0    0         HP                   Victus 15-fb0157AX Gaming Laptop   49900
# 1    1         HP                                15s-fq5007TU Laptop   39900
# 2    2       Acer                               One 14 Z8-415 Laptop   26990
# 3    3     Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729
# 4    4      Apple                    MacBook Air 2020 MGND3HN Laptop   69990
# 5    5       Acer                            Extensa EX214-53 Laptop   39990
# 6    6       Dell                  Inspiron 3520 D560896WIN9B Laptop   36790
# 7    7       Acer                Nitro V ANV15-51 2023 Gaming Laptop   76990
# 8    8       Asus                 Vivobook 15 X1502ZA-EJ523WS Laptop   48990
# 9    9    Samsung                         Galaxy Book2 Pro 13 Laptop   74990
# 10  10     Lenovo                       V15 G3 IAP 82TTA08AIN Laptop   49990
# ...

# %%
plt.plot(df['brand'], df['price'], label = 'brand')
plt.plot(df['name'], df['price'], label = 'name')
plt.plot(df['processor'], df['price'], label = 'processor')
plt.plot(df['Ram'], df['price'], label = 'RAM')
plt.plot(df['ROM'], df['price'], label = 'ROM')
plt.plot(df['display_size'], df['price'], label = 'display_size')
plt.legend()
plt.show()

# %%
plt.plot(df['brand'], label = 'brand')
plt.plot(df['name'], label = 'name')
plt.plot(df['processor'],  label = 'processor')
plt.plot(df['Ram'], label = 'RAM')
plt.plot(df['ROM'], label = 'ROM')
plt.plot(df['display_size'], label = 'display_size')
plt.title('line plot')
plt.legend()
plt.show()

# %%
plt.scatter(df['brand'], df['price'], label = 'brand')
plt.scatter(df['name'], df['price'], label = 'name')
plt.scatter(df['processor'], df['price'], label = 'processor')
plt.scatter(df['Ram'], df['price'], label = 'RAM')
plt.scatter(df['ROM'], df['price'], label = 'ROM')
plt.scatter(df['display_size'], df['price'], label = 'display_size')
plt.legend()
plt.title('scatter plot')
plt.show()

# %%
plt.barh(df['brand'], label = 'brand',width = df['price'])
plt.barh(df['Ram'], label = 'RAM',width = df['price'])
plt.barh(df['ROM'], label = 'ROM',width = df['price'])
plt.legend()
plt.title(' bar plot')
plt.show()

# %%
plt.barh(df['processor'], label = 'processor',width = df['price'])
plt.title('bar plot')
plt.legend()
plt.show()

# %%
plt.hist(df['brand'],  label = 'brand')
plt.hist(df['name'], label = 'name')
plt.hist(df['processor'],  label = 'processor')
plt.hist(df['Ram'],  label = 'RAM')
plt.hist(df['ROM'],  label = 'ROM')
plt.hist(df['display_size'],  label = 'display_size')
plt.title('histogram plot')
plt.legend()
plt.show()

# %%
pd.plotting.scatter_matrix(df, alpha=0.8, figsize=(10, 10), diagonal='hist')
plt.suptitle('Scatter Matrix', y=0.92)
# Out:
# Text(0.5, 0.92, 'Scatter Matrix')

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder          
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('titanic.csv')
df2.isnull().sum()
df2.drop('Cabin', axis=1, inplace=True) 
df2.dropna(inplace=True)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
le = LabelEncoder()
df2['Sex'] = le.fit_transform(df2['Sex'])

# %%
X = df2[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = df2['Survived']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=65)

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt_model = dt.fit(x_train, y_train)

# %%
fig = plt.figure(figsize=(12, 10))
tree.plot_tree(dt_model, feature_names=list(X.columns), class_names=['Not survived', 'Survived'])
plt.show()
print("Accuracy score on Testing set: ", dt_model.score(x_test, y_test))
# Out:
# Accuracy score on Testing set:  0.7832167832167832

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...
